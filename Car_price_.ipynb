# %% [markdown]
# <a href="https://colab.research.google.com/github/Chandrashekhar569/OIBSIP/blob/main/Car_price_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **👉Importing the Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **👉Importing the Dataset**

# %%
data = pd.read_csv('/content/CarPrice.csv')
data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %% [markdown]
# # **👉Doing Some EDA**

# %% [markdown]
# **Data Shape**

# %%
data.shape
# Out:
# (205, 26)

# %% [markdown]
# Here is Rows = 205 and Columns = 26

# %% [markdown]
# **👉Checking data informations**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %% [markdown]
# You can see here is there some columns integer, float and categorical data type and not any in columns have null values.

# %% [markdown]
# **👉Data Describe**

# %%
data.describe().round(2)
# Out:
#        car_ID  symboling  wheelbase  carlength  carwidth  carheight  \
# count  205.00     205.00     205.00     205.00    205.00     205.00
# mean   103.00       0.83      98.76     174.05     65.91      53.72
# std     59.32       1.25       6.02      12.34      2.15       2.44
# min      1.00      -2.00      86.60     141.10     60.30      47.80
# 25%     52.00       0.00      94.50     166.30     64.10      52.00
# 50%    103.00       1.00      97.00     173.20     65.50      54.10
# 75%    154.00       2.00     102.40     183.10     66.90      55.50
# max    205.00       3.00     120.90     208.10     72.30      59.80
#
#        curbweight  enginesize  boreratio  stroke  compressionratio  \
# count      205.00      205.00     205.00  205.00            205.00
# mean      2555.57      126.91       3.33    3.26             10.14
# std        520.68       41.64       0.27    0.31              3.97
# min       1488.00       61.00       2.54    2.07              7.00
# ...

# %% [markdown]
# **👉Price Describe**

# %%
data['price'].describe().round(2)
# Out:
# count      205.00
# mean     13276.71
# std       7988.85
# min       5118.00
# 25%       7788.00
# 50%      10295.00
# 75%      16503.00
# max      45400.00
# Name: price, dtype: float64

# %% [markdown]
# **Hare Avg Price =  13276.71**

# %% [markdown]
# **👉Car Name**

# %%
plt.figure(figsize = [30, 10])
sns.countplot(x='CarName',data=data)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **👉Symboling According to car sefty**

# %%
data['symboling'].value_counts()
# Out:
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: symboling, dtype: int64

# %%
sns.countplot(x='symboling',data=data)
plt.show()

# %% [markdown]
# **👉Car Body Type**

# %%
data['carbody'].value_counts()
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64

# %%
sns.countplot(x='carbody',data=data)
plt.show()

# %% [markdown]
# # **ML**

# %% [markdown]
# **👉Making Dataset Copy**

# %%
data2 = data.copy()

# %% [markdown]
# **👉Label Encoding For categorical Data**

# %%
from sklearn import preprocessing
label = preprocessing.LabelEncoder()
data2['drivewheel'] = label.fit_transform(data2['drivewheel'])
data2['carbody'] = label.fit_transform(data2['carbody'])
data2['cylindernumber'] = label.fit_transform(data2['cylindernumber'])
data2['fueltype'] = label.fit_transform(data2['fueltype'])
data2['aspiration'] = label.fit_transform(data2['aspiration'])
data2['doornumber'] = label.fit_transform(data2['doornumber'])
data2['enginelocation'] = label.fit_transform(data2['enginelocation'])
data2['enginetype'] = label.fit_transform(data2['enginetype'])
data2['fuelsystem'] = label.fit_transform(data2['fuelsystem'])
data2.head()
# Out:
#    car_ID  symboling                   CarName  fueltype  aspiration  \
# 0       1          3        alfa-romero giulia         1           0
# 1       2          3       alfa-romero stelvio         1           0
# 2       3          1  alfa-romero Quadrifoglio         1           0
# 3       4          2               audi 100 ls         1           0
# 4       5          2                audi 100ls         1           0
#
#    doornumber  carbody  drivewheel  enginelocation  wheelbase  ...  \
# 0           1        0           2               0       88.6  ...
# 1           1        0           2               0       88.6  ...
# 2           1        2           2               0       94.5  ...
# 3           0        3           1               0       99.8  ...
# 4           0        3           0               0       99.4  ...
#
#    enginesize  fuelsystem  boreratio  stroke  compressionratio  horsepower  \
# ...

# %% [markdown]
# **👉Droping unwanted columns**

# %%
cleandata = data2.drop(columns=["price","car_ID","CarName"])

# %%
r = cleandata.iloc[ :, :-1].values
o = data2.iloc[:, -1].values

# %% [markdown]
# **👉Splitting the dataset into the training set and test set**

# %%
from sklearn.model_selection import train_test_split
r_train, r_test, o_train, o_test = train_test_split(r , o, test_size = 0.2, random_state = 1)

# %% [markdown]
# **👉Feature Scaling**

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
r_train[:, :-1] = sc.fit_transform(r_train[ :, :-1])
r_test[:, :-1] = sc.transform(r_test[:, :-1])

# %% [markdown]
# **👉Importing regression Model**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# **👉Training regression Model on the Trainning set**

# %%
models2 = [
    LinearRegression(),
    DecisionTreeRegressor(),
    RandomForestRegressor(),
    SVR(),
    KNeighborsRegressor(),
    MLPRegressor()
]
for model2 in models2:

    model2.fit(r_train, o_train)

    o_pred = model2.predict(r_test)

    r2 = round(r2_score(o_test, o_pred), 2)

    print(type(model2).__name__, "R2 score:", r2)
# Out:
# LinearRegression R2 score: 0.73
# DecisionTreeRegressor R2 score: 0.87
# RandomForestRegressor R2 score: 0.91
# SVR R2 score: -0.03
# KNeighborsRegressor R2 score: 0.78
# MLPRegressor R2 score: -2.62
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# **✨You can see here our best regression model is Random Forest with got 91% accuracy🎉🎉**
